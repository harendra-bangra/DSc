# %% [markdown]
# # **Data Science Lab Assignment 7**
# Name: Harendra Bangra
#
# Roll No: 197231
#
# Section: CSE-B

# %% [markdown]
# 1. Implement a Simple Neural Network Model and predict if a person will buy insurance or not for the given dataset.

# %%
# Question 1
# Implementation of the SNN from Scratch
import pandas as pd
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

from google.colab import drive
drive.mount('/content/drive')

# PART A
df = pd.read_csv("insurance_data.csv")
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     age  Affordability  bought_insurance
# 0    22              1                 0
# 1    25              1                 0
# 2    47              0                 1
# 3    52              1                 0
# 4    46              1                 1
# 5    56              0                 1
# 6    55              1                 0
# 7    60              1                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              0                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              0                 1
# 18   19              1                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# 22   40              1                 1
# 23   45              0                 1
# 24   50              1                 1
# 25   54              1                 1
# 26   23              1                 0

# %%
# variable used
# Independent variable = All col - {bought_insurance} = X
# Dependent variable = bought_insurance = Y

X, Y = df.drop(columns = ["bought_insurance"]), df['bought_insurance']
# Scaling
scaler = StandardScaler()
X = scaler.fit_transform(X)
print("Independent Features :-\n",np.around(X,2))
print("Dependent Feature :-\n",Y)
# Out:
# Independent Features :-
#  [[-1.14  0.71]
#  [-0.95  0.71]
#  [ 0.47 -1.41]
#  [ 0.8   0.71]
#  [ 0.41  0.71]
#  [ 1.06 -1.41]
#  [ 0.99  0.71]
#  [ 1.32  0.71]
#  [ 1.45  0.71]
#  [ 1.38  0.71]
#  [-1.4  -1.41]
#  [-0.76  0.71]
#  [-0.82 -1.41]
#  [-0.69 -1.41]
#  [ 0.6   0.71]
#  [ 0.99  0.71]
#  [-0.95 -1.41]
#  [ 1.19 -1.41]
#  [-1.34  0.71]
#  [-1.4   0.71]
#  [-1.21  0.71]
#  [-0.88 -1.41]
#  [ 0.02  0.71]
#  [ 0.35 -1.41]
#  [ 0.67  0.71]
#  [ 0.93  0.71]
#  [-1.08  0.71]]
# Dependent Feature :-
#  0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
# Split a dataset into 80/20 train/test set
from random import randrange

def train_test_split(x, y, split):
  x_train, y_train = list(),list()
  train_size = split * len(x)
  x_test, y_test = list(x), list(y)
  while len(x_train) < train_size:
    idx = randrange(len(x_test))
    x_train.append(x_test.pop(idx))
    y_train.append(y_test.pop(idx))
  return np.array(x_train), np.array(x_test), np.array(y_train), np.array(y_test)

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,0.8)

print("Independent Training Feature Shape :-",X_train.shape)
print("Independent Testing Feature Shape :-",X_test.shape)
print("Dependent Training Feature Shape :- ",Y_train.shape)
print("Dependent Testing Feature Shape :- ",Y_test.shape)
# Out:
# Independent Training Feature Shape :- (22, 2)
# Independent Testing Feature Shape :- (5, 2)
# Dependent Training Feature Shape :-  (22,)
# Dependent Testing Feature Shape :-  (5,)

# %% [markdown]
# First We build a model in keras

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, Y_train, epochs=50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 386ms/step - loss: 0.5885 - accuracy: 0.7273
# Epoch 2/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5880 - accuracy: 0.7273
# Epoch 3/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5875 - accuracy: 0.7273
# Epoch 4/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5870 - accuracy: 0.7273
# Epoch 5/50
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5865 - accuracy: 0.7273
# Epoch 6/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5860 - accuracy: 0.7273
# Epoch 7/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5855 - accuracy: 0.7273
# Epoch 8/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5850 - accuracy: 0.7273
# Epoch 9/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5845 - accuracy: 0.7273
# Epoch 10/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5841 - accuracy: 0.7273
# Epoch 11/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5836 - accuracy: 0.7273
# Epoch 12/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5831 - accuracy: 0.7273
# Epoch 13/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5826 - accuracy: 0.7273
# Epoch 14/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5821 - accuracy: 0.7273
# Epoch 15/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5816 - accuracy: 0.7273
# Epoch 16/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5811 - accuracy: 0.7273
# Epoch 17/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5806 - accuracy: 0.7273
# Epoch 18/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5802 - accuracy: 0.7273
# Epoch 19/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5797 - accuracy: 0.7273
# Epoch 20/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5792 - accuracy: 0.7273
# Epoch 21/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5787 - accuracy: 0.7273
# Epoch 22/50
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5782 - accuracy: 0.7273
# Epoch 23/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5778 - accuracy: 0.7273
# Epoch 24/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5773 - accuracy: 0.7273
# Epoch 25/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5768 - accuracy: 0.7273
# Epoch 26/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5763 - accuracy: 0.7273
# Epoch 27/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5758 - accuracy: 0.7273
# Epoch 28/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5754 - accuracy: 0.7273
# Epoch 29/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5749 - accuracy: 0.7273
# Epoch 30/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5744 - accuracy: 0.7273
# Epoch 31/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5739 - accuracy: 0.7273
# Epoch 32/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5735 - accuracy: 0.7273
# Epoch 33/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5730 - accuracy: 0.7273
# Epoch 34/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5725 - accuracy: 0.7273
# Epoch 35/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5720 - accuracy: 0.7273
# Epoch 36/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5716 - accuracy: 0.7273
# Epoch 37/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5711 - accuracy: 0.7273
# Epoch 38/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5706 - accuracy: 0.7273
# Epoch 39/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5702 - accuracy: 0.7273
# Epoch 40/50
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5697 - accuracy: 0.7273
# Epoch 41/50
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5692 - accuracy: 0.7273
# Epoch 42/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5688 - accuracy: 0.7273
# Epoch 43/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5683 - accuracy: 0.7273
# Epoch 44/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5678 - accuracy: 0.7273
# Epoch 45/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5674 - accuracy: 0.7273
# Epoch 46/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5669 - accuracy: 0.7273
# Epoch 47/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5665 - accuracy: 0.7273
# Epoch 48/50
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5660 - accuracy: 0.7273
# Epoch 49/50
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5655 - accuracy: 0.7273
# Epoch 50/50
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5651 - accuracy: 0.7273

# %%
#Evaluate the model on test set
model.evaluate(X_test,Y_test)
# Out:
# 1/1 [==============================] - 0s 108ms/step - loss: 0.6404 - accuracy: 0.8000
# [0.6404302716255188, 0.800000011920929]

# %%
# Predict Values
model.predict(X_test)
# Out:
# array([[0.38249207],
#        [0.759773  ],
#        [0.85356534],
#        [0.89114726],
#        [0.3356397 ]], dtype=float32)

# %% [markdown]
# Instead of model.predict, We write our own prediction function

# %%
# Sigmoid Function
def sigmoid_numpy(X):
   return 1/(1+np.exp(-X))

# Log_Loss Function
def log_loss(y_true, y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# Neural Network Function
class myNN:
    def __init__(self):
        self.w1 = 1 
        self.w2 = 1
        self.bias = 0
        
    def fit(self, X, y, epochs, loss_thresold):
        self.w1, self.w2, self.bias = self.gradient_descent(X[:,0],X[:,1],y, epochs, loss_thresold)
        print(f"Final weights and bias: w1: {self.w1}, w2: {self.w2}, bias: {self.bias}")
        
    def predict(self, X_test):
        weighted_sum = self.w1*X_test[:,0] + self.w2*X_test[:,1] + self.bias
        return sigmoid_numpy(weighted_sum)

    def gradient_descent(self, age,affordability, y_true, epochs, loss_thresold):
        w1 = w2 = 1
        bias = 0
        rate = 0.5
        n = len(age)
        for i in range(epochs):
            weighted_sum = w1 * age + w2 * affordability + bias
            y_predicted = sigmoid_numpy(weighted_sum)
            loss = log_loss(y_true, y_predicted)
            
            w1d = (1/n)*np.dot(np.transpose(age),(y_predicted-y_true)) 
            w2d = (1/n)*np.dot(np.transpose(affordability),(y_predicted-y_true)) 

            bias_d = np.mean(y_predicted-y_true)
            w1 = w1 - rate * w1d
            w2 = w2 - rate * w2d
            bias = bias - rate * bias_d
            
            if i%50==0:
                print (f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
            
            if loss<=loss_thresold:
                print (f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
                break

        return w1, w2, bias

# Get Custom Model
customModel = myNN()
customModel.fit(X_train, Y_train, epochs=8000, loss_thresold=0.4631)
# Out:
# Epoch:0, w1:1.084099771991269, w2:0.8725322537915615, bias:0.03582801205195723, loss:0.5884838411499618
# Epoch:4, w1:1.3459941228586632, w2:0.4804134534672551, bias:0.1439232129714443, loss:0.4489554319855335
# Final weights and bias: w1: 1.3459941228586632, w2: 0.4804134534672551, bias: 0.1439232129714443

# %%
#Predict using custom model

print("Actual values : ", Y_test)
print("Predicted values : ",customModel.predict(X_test))
# Out:
# Actual values :  [0 1 0 1 0]
# Predicted values :  [0.25819743 0.73794958 0.86048812 0.90507339 0.21136856]

# %% [markdown]
# 2. Use the given dataset and build a customer churn prediction model using artificial neural network.\
# [Concept used: ANN Classification, Use Multiple Hidden Layers, Confusion Matrix to check the
# accuracy rate of the model]\
# Dataset: https://www.kaggle.com/mltuts/churn-modelling-data?select=Churn_Modelling.csv

# %%
import keras
from keras.models import Sequential   # For building the Neural Network layer by layer
from keras.layers import Dense        # used to add fully connected layer in ANN#Simple Neural Network Model Code using Tensorflow
import pandas as pd                   # import pandas and numpy for datafram and numpy operations
import numpy as np
import matplotlib.pyplot as plt       # import matplotlib for graphical visualizations 
import io                             # import io for reading csv files
from sklearn.preprocessing import StandardScaler      # for standardizing the data
from sklearn.metrics import accuracy_score            # to determine the accuracy score
from sklearn.preprocessing import OneHotEncoder

## importing the dataset
df= pd.read_csv('Churn_Modelling.csv')           
print(df.head())

print("The dataset after dopping first 3 columns are : ")
df.drop(df.columns[[0,1,2]],axis=1,inplace=True)    # we drop few columns because we dont need them 
print(df.head())
n=df.shape[1]               # n--> number of columns
m=df.shape[0]               # m--> number of rows


def texttonum(vec):
  visited=[]
  res=[]
  index=0
  for i in vec:
    if(i in visited):
      res.append(visited.index(i))
    else:
      visited.append(i)
      res.append(index)
      index=index+1
  return res
df.iloc[:,1]=np.array(texttonum(df.iloc[:,1].tolist()))        # converting the text data in geography and gender column into categorical data
df.iloc[:,2]=np.array(texttonum(df.iloc[:,2].tolist()))        # we make 0 --> female 1--> male
print(df.head())

x_train=np.array(df.iloc[:int(0.8*m),:n-1])      # we take 80% of rows in training data
y_train=np.array(df.iloc[:int(0.8*m),-1])        # only the last column is in y_train  
x_test=np.array(df.iloc[int(0.8*m):,:n-1])       # only 20 % of rows is in testing dataset
y_test=np.array(df.iloc[int(0.8*m):,-1])         # splitting into training and testing dataset



sc = StandardScaler()
x_train_scaled= sc.fit_transform(x_train)    # here we standardize the training and testing data using standardscaler()
x_test_scaled=sc.fit_transform(x_test)       # we standardize them so that they are easy to compute


model=Sequential()                                      # we create our neural network model here
model.add(Dense(10, input_dim=10, activation='relu'))     # input dimensions to this layer is 2 and we use reLU activation function
model.add(Dense(8, input_dim=10, activation='relu'))     # input dimensions to this layer is 2 and we use reLU activation function 
model.add(Dense(6, input_dim=8, activation='relu'))     # input dimensions to this layer is 2 and we use reLU activation function 
model.add(Dense(1, activation='sigmoid'))               # finally the output dimension has only 1 parameter(0 or 1) so we use sigmoid activation function  
                                                        # output dimension has 1 parameter as output

#"compile" is a method of Tensorflow. “adam’ is the optimizer that can perform the gradient descent.
# loss function as binary_crossentropy as we have 2 cases only 0 or 1
# The optimizer updates the weights during training and reduces the loss.                                                        
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

model.fit(x_train_scaled, y_train, epochs=50,batch_size=250) # we fit our model using this
model.evaluate(x_test_scaled,y_test)                        # we evaluate using our scaled testing data
y_pred=model.predict(x_test_scaled)                         # we predict based on scaled testing data
actual_res=y_test.tolist()                                  # actual_res contains the actual result list  
pred_res=y_pred.tolist()                                    # pred_res contains the predicted result list

for i in range(len(pred_res)):                    # since we used sigmoid function as our last activation layer
  if(pred_res[i][0]>=0.5):                        # we convert those values into either 0 or 1 based on whether they are greater than 0.5 or not
    pred_res[i]=1                                 # if greater or equal to 0.5 we make it 1
  else:                                            
    pred_res[i]=0                                 # if less than 0.5 we make it equal to 0 

a = accuracy_score(pred_res,actual_res)                     # we compute the accuracy based on accuracy_score function from sklearn.metrics
print('Accuracy is:', a*100)                                # final accuracy result
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# The dataset after dopping first 3 columns are :
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          1       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          1       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0
# Epoch 1/50
# 32/32 [==============================] - 1s 2ms/step - loss: 0.7362 - accuracy: 0.2476
# Epoch 2/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6955 - accuracy: 0.5537
# Epoch 3/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6744 - accuracy: 0.7538
# Epoch 4/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6484 - accuracy: 0.7941
# Epoch 5/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.7952
# Epoch 6/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5547 - accuracy: 0.7941
# Epoch 7/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5136 - accuracy: 0.7943
# Epoch 8/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4818 - accuracy: 0.7955
# Epoch 9/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4589 - accuracy: 0.7987
# Epoch 10/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.8059
# Epoch 11/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4292 - accuracy: 0.8151
# Epoch 12/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4164 - accuracy: 0.8234
# Epoch 13/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4041 - accuracy: 0.8291
# Epoch 14/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8360
# Epoch 15/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3844 - accuracy: 0.8414
# Epoch 16/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3778 - accuracy: 0.8444
# Epoch 17/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3731 - accuracy: 0.8450
# Epoch 18/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3698 - accuracy: 0.8470
# Epoch 19/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3669 - accuracy: 0.8476
# Epoch 20/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8485
# Epoch 21/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8490
# Epoch 22/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8494
# Epoch 23/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3606 - accuracy: 0.8504
# Epoch 24/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3590 - accuracy: 0.8510
# Epoch 25/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3578 - accuracy: 0.8506
# Epoch 26/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3567 - accuracy: 0.8516
# Epoch 27/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3560 - accuracy: 0.8518
# Epoch 28/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3550 - accuracy: 0.8534
# Epoch 29/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3545 - accuracy: 0.8519
# Epoch 30/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.8541
# Epoch 31/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3527 - accuracy: 0.8543
# Epoch 32/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3520 - accuracy: 0.8541
# Epoch 33/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3515 - accuracy: 0.8531
# Epoch 34/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3507 - accuracy: 0.8554
# Epoch 35/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8550
# Epoch 36/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8546
# Epoch 37/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.8559
# Epoch 38/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3479 - accuracy: 0.8553
# Epoch 39/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3472 - accuracy: 0.8561
# Epoch 40/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8565
# Epoch 41/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8571
# Epoch 42/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3457 - accuracy: 0.8561
# Epoch 43/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8559
# Epoch 44/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8572
# Epoch 45/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3439 - accuracy: 0.8569
# Epoch 46/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8565
# Epoch 47/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8570
# Epoch 48/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8566
# Epoch 49/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8569
# Epoch 50/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.8577
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3711 - accuracy: 0.8430
# Accuracy is: 84.3

# %%
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('197231-DS-7.ipynb')
# Out:
# --2022-03-28 09:01:41--  https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1864 (1.8K) [text/plain]
# Saving to: ‘colab_pdf.py’
#
# colab_pdf.py        100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2022-03-28 09:01:41 (24.6 MB/s) - ‘colab_pdf.py’ saved [1864/1864]
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Extracting templates from packages: 100%
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/197231-DS-7.ipynb to pdf
# [NbConvertApp] Writing 66248 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', './notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 66183 bytes to /content/drive/My Drive/197231-DS-7.pdf
# 'File ready to be Downloaded and Saved to Drive'
