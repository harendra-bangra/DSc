# %% [markdown]
# # Data Science Lab Assignment 8
#
# ---
#
#
#
# ---
#
#
# Name: Harendra Bangra
#
# Roll No: 197231
#
# Section: CSE-B

# %% [markdown]
# Implement neural network from scratch using python for the following datasets and predict the values for the following datasets:
#
# 1. Boston House prices dataset: https://www.kaggle.com/fedesoriano/the-boston-houseprice-data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def relu(z):
    a = np.maximum(0,z)
    return a

def initialize_params(layer_sizes):
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

def compute_cost(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = initialize_params(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

# %%
#Question 1
#predict the values for Boston House prices dataset
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.03
layer_sizes=[13,5,5,1]
df =  pd.read_csv('boston.csv')
df.head()
n=df.shape[1]               # n--> number of columns
m=df.shape[0]               # m--> number of rows

x_train=np.array(df.iloc[:int(0.9*m),:n-1])      # we take 90% of rows in training data
y_train=np.array(df.iloc[:int(0.9*m),-1])        # only the last column is in y_train  
x_test=np.array(df.iloc[int(0.9*m):,:n-1])       # only 10 % of rows is in testing dataset
y_test=np.array(df.iloc[int(0.9*m):,-1])         # splitting into training and testing dataset 
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)
y_predict = predict(x_test,params)
print(y_predict)

# %%
#Question 2
#predict the values for Boston House prices dataset
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.03
layer_sizes=[7,5,5,1]
df =  pd.read_csv('seeds.csv')
df.head()
n=df.shape[1]               # n--> number of columns
m=df.shape[0]               # m--> number of rows

x_train=np.array(df.iloc[:int(0.9*m),:n-1])      # we take 90% of rows in training data
y_train=np.array(df.iloc[:int(0.9*m),-1])        # only the last column is in y_train  
x_test=np.array(df.iloc[int(0.9*m):,:n-1])       # only 10 % of rows is in testing dataset
y_test=np.array(df.iloc[int(0.9*m):,-1])         # splitting into training and testing dataset 
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)
y_predict = predict(x_test,params)
print(y_predict)
# Out:
# Cost at iteration 1 = 2.075208119800513
#
# Cost at iteration 2 = 2.0746141624141843
#
# Cost at iteration 3 = 2.074020404097841
#
# Cost at iteration 4 = 2.0734268447847595
#
# Cost at iteration 5 = 2.0728334844082394
#
# Cost at iteration 6 = 2.0722403229015995
#
# Cost at iteration 7 = 2.071647360198183
#
# Cost at iteration 8 = 2.071054596231356
#
# Cost at iteration 9 = 2.070462030934506
#
# Cost at iteration 10 = 2.0698696642410424
#
# Cost at iteration 11 = 2.069277496084399
#
# Cost at iteration 12 = 2.0686855263980295
#
# Cost at iteration 13 = 2.06809375511541
#
# Cost at iteration 14 = 2.0675021821700414
#
# Cost at iteration 15 = 2.066910807495444
#
# Cost at iteration 16 = 2.066319631025163
#
# Cost at iteration 17 = 2.0657286526927634
#
# Cost at iteration 18 = 2.0651378724318334
#
# Cost at iteration 19 = 2.0645472901759847
#
# Cost at iteration 20 = 2.0639569058588494
#
# Cost at iteration 21 = 2.0633667194140832
#
# Cost at iteration 22 = 2.0627767307753637
#
# Cost at iteration 23 = 2.0621869398763897
#
# Cost at iteration 24 = 2.061597346650883
#
# Cost at iteration 25 = 2.0610079510325887
#
# Cost at iteration 26 = 2.060418752955273
#
# Cost at iteration 27 = 2.0598297523527234
#
# Cost at iteration 28 = 2.059240949158751
#
# Cost at iteration 29 = 2.0586523433071893
#
# Cost at iteration 30 = 2.058063934731893
#
# Cost at iteration 31 = 2.0574757233667387
#
# Cost at iteration 32 = 2.0568877091456272
#
# Cost at iteration 33 = 2.056299892002479
#
# Cost at iteration 34 = 2.0557122718712373
#
# Cost at iteration 35 = 2.05512484868587
#
# Cost at iteration 36 = 2.0545376223803635
#
# Cost at iteration 37 = 2.053950592888728
#
# Cost at iteration 38 = 2.053363760144996
#
# Cost at iteration 39 = 2.052777124083222
#
# Cost at iteration 40 = 2.052190684637482
#
# Cost at iteration 41 = 2.0516044417418757
#
# Cost at iteration 42 = 2.0510183953305234
#
# Cost at iteration 43 = 2.0504325453375665
#
# Cost at iteration 44 = 2.0498468916971713
#
# Cost at iteration 45 = 2.049261434343524
#
# Cost at iteration 46 = 2.048676173210834
#
# Cost at iteration 47 = 2.0480911082333315
#
# Cost at iteration 48 = 2.047506239345271
#
# Cost at iteration 49 = 2.0469215664809264
#
# Cost at iteration 50 = 2.0463370895745956
#
# Cost at iteration 51 = 2.045752808560597
#
# Cost at iteration 52 = 2.0451687233732723
#
# Cost at iteration 53 = 2.0445848339469848
#
# Cost at iteration 54 = 2.0440011402161193
#
# Cost at iteration 55 = 2.0434176421150827
#
# Cost at iteration 56 = 2.042834339578306
#
# Cost at iteration 57 = 2.0422512325402375
#
# Cost at iteration 58 = 2.0416683209353534
#
# Cost at iteration 59 = 2.0410856046981456
#
# Cost at iteration 60 = 2.040503083763134
#
# Cost at iteration 61 = 2.039920758064856
#
# Cost at iteration 62 = 2.0393386275378735
#
# Cost at iteration 63 = 2.038756692115546
#
# Cost at iteration 64 = 2.038174951732511
#
# Cost at iteration 65 = 2.0375934063245866
#
# Cost at iteration 66 = 2.03701205582642
#
# Cost at iteration 67 = 2.036430900172683
#
# Cost at iteration 68 = 2.0358499392980676
#
# Cost at iteration 69 = 2.035269173137288
#
# Cost at iteration 70 = 2.03468860162508
#
# Cost at iteration 71 = 2.034108224695152
#
# Cost at iteration 72 = 2.0335280422818305
#
# Cost at iteration 73 = 2.032948054321422
#
# Cost at iteration 74 = 2.03236826074875
#
# Cost at iteration 75 = 2.0317886614986596
#
# Cost at iteration 76 = 2.0312092565060187
#
# Cost at iteration 77 = 2.0306300457057156
#
# Cost at iteration 78 = 2.030051029032663
#
# Cost at iteration 79 = 2.0294722064217936
#
# Cost at iteration 80 = 2.0288935778080597
#
# Cost at iteration 81 = 2.028315143126441
#
# Cost at iteration 82 = 2.0277369023119336
#
# Cost at iteration 83 = 2.0271588552995587
#
# Cost at iteration 84 = 2.026581002024358
#
# Cost at iteration 85 = 2.0260033424213955
#
# Cost at iteration 86 = 2.0254258764254707
#
# Cost at iteration 87 = 2.024848603969701
#
# Cost at iteration 88 = 2.0242715249914918
#
# Cost at iteration 89 = 2.023694639425993
#
# Cost at iteration 90 = 2.0231179472083762
#
# Cost at iteration 91 = 2.0225414482738366
#
# Cost at iteration 92 = 2.0219651425575904
#
# Cost at iteration 93 = 2.0213890299948742
#
# Cost at iteration 94 = 2.0208131105209475
#
# Cost at iteration 95 = 2.0202373840710925
#
# Cost at iteration 96 = 2.01966185058061
#
# Cost at iteration 97 = 2.019086509984826
#
# Cost at iteration 98 = 2.0185113622190864
#
# Cost at iteration 99 = 2.0179364072187584
#
# Cost at iteration 100 = 2.017361644919232
#
# Cost at iteration 101 = 2.016787075255918
#
# Cost at iteration 102 = 2.0162126981642485
#
# Cost at iteration 103 = 2.015638513579679
#
# Cost at iteration 104 = 2.0150645214353533
#
# Cost at iteration 105 = 2.014490721669094
#
# Cost at iteration 106 = 2.0139171142164276
#
# Cost at iteration 107 = 2.0133436990128954
#
# Cost at iteration 108 = 2.012770475994059
#
# Cost at iteration 109 = 2.012197445095503
#
# Cost at iteration 110 = 2.0116246062528327
#
# Cost at iteration 111 = 2.011051959401676
#
# Cost at iteration 112 = 2.010479504477682
#
# Cost at iteration 113 = 2.0099072414165193
#
# Cost at iteration 114 = 2.0093351701538817
#
# Cost at iteration 115 = 2.008763290625483
#
# Cost at iteration 116 = 2.0081916027670568
#
# Cost at iteration 117 = 2.0076201065143606
#
# Cost at iteration 118 = 2.0070488018031725
#
# Cost at iteration 119 = 2.0064776885692925
#
# Cost at iteration 120 = 2.005906766748541
#
# Cost at iteration 121 = 2.005336036276762
#
# Cost at iteration 122 = 2.0047654970879383
#
# Cost at iteration 123 = 2.0041951491193815
#
# Cost at iteration 124 = 2.0036249923074543
#
# Cost at iteration 125 = 2.003055026586119
#
# Cost at iteration 126 = 2.0024852518929106
#
# Cost at iteration 127 = 2.001915668164183
#
# Cost at iteration 128 = 2.0013462753359295
#
# Cost at iteration 129 = 2.0007770733441634
#
# Cost at iteration 130 = 2.000208062124922
#
# Cost at iteration 131 = 1.9996392416142625
#
# Cost at iteration 132 = 1.9990706117482635
#
# Cost at iteration 133 = 1.998502172463026
#
# Cost at iteration 134 = 1.9979339236946705
#
# Cost at iteration 135 = 1.9973658653793418
#
# Cost at iteration 136 = 1.9967979974532035
#
# Cost at iteration 137 = 1.9962303198524423
#
# Cost at iteration 138 = 1.9956628325132657
#
# Cost at iteration 139 = 1.9950955353719009
#
# Cost at iteration 140 = 1.9945284283646
#
# Cost at iteration 141 = 1.9939615114276332
#
# Cost at iteration 142 = 1.9933947844972943
#
# Cost at iteration 143 = 1.9928282475098973
#
# Cost at iteration 144 = 1.9922619004017772
#
# Cost at iteration 145 = 1.9916957431092923
#
# Cost at iteration 146 = 1.9911297755688193
#
# Cost at iteration 147 = 1.9905639977167593
#
# Cost at iteration 148 = 1.9899984094895327
#
# Cost at iteration 149 = 1.9894330108235807
#
# Cost at iteration 150 = 1.9888678016553685
#
# Cost at iteration 151 = 1.9883027819213794
#
# Cost at iteration 152 = 1.987737951558121
#
# Cost at iteration 153 = 1.9871733105021196
#
# Cost at iteration 154 = 1.9866088586899247
#
# Cost at iteration 155 = 1.986044596058106
#
# Cost at iteration 156 = 1.9854805225432546
#
# Cost at iteration 157 = 1.984916638081983
#
# Cost at iteration 158 = 1.9843529426109259
#
# Cost at iteration 159 = 1.9837894360667365
#
# Cost at iteration 160 = 1.9832261183860924
#
# Cost at iteration 161 = 1.982662989505691
#
# Cost at iteration 162 = 1.98210004936225
#
# Cost at iteration 163 = 1.981537297892511
#
# Cost at iteration 164 = 1.980974735033233
#
# Cost at iteration 165 = 1.9804123607211999
#
# Cost at iteration 166 = 1.9798501748932142
#
# Cost at iteration 167 = 1.9792881774861013
#
# Cost at iteration 168 = 1.9787263684367071
#
# Cost at iteration 169 = 1.978164747681898
#
# Cost at iteration 170 = 1.9776033151585621
#
# Cost at iteration 171 = 1.97704207080361
#
# Cost at iteration 172 = 1.9764810145539708
#
# Cost at iteration 173 = 1.975920146346597
#
# Cost at iteration 174 = 1.9753594661184601
#
# Cost at iteration 175 = 1.9747989738065561
#
# Cost at iteration 176 = 1.9742386693478986
#
# Cost at iteration 177 = 1.973678552679524
#
# Cost at iteration 178 = 1.9731186237384892
#
# Cost at iteration 179 = 1.9725588824610314
#
# Cost at iteration 180 = 1.971999328784971
#
# Cost at iteration 181 = 1.9714399626475503
#
# Cost at iteration 182 = 1.9708807839859095
#
# Cost at iteration 183 = 1.9703217927372125
#
# Cost at iteration 184 = 1.9697629888386423
#
# Cost at iteration 185 = 1.9692043722274049
#
# Cost at iteration 186 = 1.9686459428407246
#
# Cost at iteration 187 = 1.9680877006158486
#
# Cost at iteration 188 = 1.9675296454900457
#
# Cost at iteration 189 = 1.966971777400604
#
# Cost at iteration 190 = 1.9664140962848349
#
# Cost at iteration 191 = 1.9658566020800674
#
# Cost at iteration 192 = 1.9652992947236547
#
# Cost at iteration 193 = 1.9647421741529698
#
# Cost at iteration 194 = 1.9641852403054065
#
# Cost at iteration 195 = 1.96362849311838
#
# Cost at iteration 196 = 1.9630719325293258
#
# Cost at iteration 197 = 1.9625155584757006
#
# Cost at iteration 198 = 1.961959370894984
#
# Cost at iteration 199 = 1.9614033697237716
#
# Cost at iteration 200 = 1.9608475549003865
#
# Cost at iteration 201 = 1.960291926362469
#
# Cost at iteration 202 = 1.959736484047581
#
# Cost at iteration 203 = 1.959181227893305
#
# Cost at iteration 204 = 1.958626157835387
#
# Cost at iteration 205 = 1.9580712738106938
#
# Cost at iteration 206 = 1.9575165757591357
#
# Cost at iteration 207 = 1.9569620636180713
#
# Cost at iteration 208 = 1.956407737325586
#
# Cost at iteration 209 = 1.9558535968196482
#
# Cost at iteration 210 = 1.955299642037988
#
# Cost at iteration 211 = 1.9547458729183538
#
# Cost at iteration 212 = 1.9541922893985177
#
# Cost at iteration 213 = 1.9536388914162706
#
# Cost at iteration 214 = 1.9530856789094246
#
# Cost at iteration 215 = 1.9525326518158146
#
# Cost at iteration 216 = 1.9519798100732921
#
# Cost at iteration 217 = 1.9514271536197336
#
# Cost at iteration 218 = 1.9508746823930354
#
# Cost at iteration 219 = 1.9503223963311125
#
# Cost at iteration 220 = 1.9497702953719036
#
# Cost at iteration 221 = 1.9492183794533664
#
# Cost at iteration 222 = 1.94866664851348
#
# Cost at iteration 223 = 1.948115102490244
#
# Cost at iteration 224 = 1.9475637413216789
#
# Cost at iteration 225 = 1.9470125649452958
#
# Cost at iteration 226 = 1.9464615732992117
#
# Cost at iteration 227 = 1.9459107663219857
#
# Cost at iteration 228 = 1.9453601439517203
#
# Cost at iteration 229 = 1.9448097061265415
#
# Cost at iteration 230 = 1.9442594527845942
#
# Cost at iteration 231 = 1.9437093838640438
#
# Cost at iteration 232 = 1.943159499303077
#
# Cost at iteration 233 = 1.9426097990399012
#
# Cost at iteration 234 = 1.9420602830127445
#
# Cost at iteration 235 = 1.9415109511598556
#
# Cost at iteration 236 = 1.9409618034195044
#
# Cost at iteration 237 = 1.9404128397289435
#
# Cost at iteration 238 = 1.9398640600262176
#
# Cost at iteration 239 = 1.9393154642509616
#
# Cost at iteration 240 = 1.9387670523415277
#
# Cost at iteration 241 = 1.9382188242359393
#
# Cost at iteration 242 = 1.9376707798722757
#
# Cost at iteration 243 = 1.9371229191896169
#
# Cost at iteration 244 = 1.9365752421263953
#
# Cost at iteration 245 = 1.9360277486210677
#
# Cost at iteration 246 = 1.935480438612109
#
# Cost at iteration 247 = 1.9349333120380166
#
# Cost at iteration 248 = 1.934386368837308
#
# Cost at iteration 249 = 1.9338396089485215
#
# Cost at iteration 250 = 1.933293032310214
#
# Cost at iteration 251 = 1.9327466388609658
#
# Cost at iteration 252 = 1.9322004285393768
#
# Cost at iteration 253 = 1.9316544012840662
#
# Cost at iteration 254 = 1.9311085570336761
#
# Cost at iteration 255 = 1.9305628957252523
#
# Cost at iteration 256 = 1.9300174172984346
#
# Cost at iteration 257 = 1.929472121692582
#
# Cost at iteration 258 = 1.9289270088464192
#
# Cost at iteration 259 = 1.9283820786986898
#
# Cost at iteration 260 = 1.927837331188157
#
# Cost at iteration 261 = 1.9272927662536066
#
# Cost at iteration 262 = 1.9267483838338424
#
# Cost at iteration 263 = 1.926204183867692
#
# Cost at iteration 264 = 1.9256601662940007
#
# Cost at iteration 265 = 1.9251163310516348
#
# Cost at iteration 266 = 1.924572678079482
#
# Cost at iteration 267 = 1.92402920731645
#
# Cost at iteration 268 = 1.9234859187014675
#
# Cost at iteration 269 = 1.9229428121734822
#
# Cost at iteration 270 = 1.9223998876714634
#
# Cost at iteration 271 = 1.921857145134401
#
# Cost at iteration 272 = 1.921314584501306
#
# Cost at iteration 273 = 1.920772205711208
#
# Cost at iteration 274 = 1.9202300087031576
#
# Cost at iteration 275 = 1.9196879934162263
#
# Cost at iteration 276 = 1.9191461597895068
#
# Cost at iteration 277 = 1.9186045077621101
#
# Cost at iteration 278 = 1.9180630372731695
#
# Cost at iteration 279 = 1.917521748261838
#
# Cost at iteration 280 = 1.916980640666737
#
# Cost at iteration 281 = 1.91643971442378
#
# Cost at iteration 282 = 1.9158989694758055
#
# Cost at iteration 283 = 1.915358405762258
#
# Cost at iteration 284 = 1.9148180232223904
#
# Cost at iteration 285 = 1.9142778217954788
#
# Cost at iteration 286 = 1.9137378014208193
#
# Cost at iteration 287 = 1.9131979620377264
#
# Cost at iteration 288 = 1.9126583035855378
#
# Cost at iteration 289 = 1.9121188260036004
#
# Cost at iteration 290 = 1.9115795292288245
#
# Cost at iteration 291 = 1.9110404132030834
#
# Cost at iteration 292 = 1.910501477865795
#
# Cost at iteration 293 = 1.909962723156398
#
# Cost at iteration 294 = 1.90942414901435
#
# Cost at iteration 295 = 1.9088857553791303
#
# Cost at iteration 296 = 1.9083475421902363
#
# Cost at iteration 297 = 1.9078095093871894
#
# Cost at iteration 298 = 1.907271656909526
#
# Cost at iteration 299 = 1.9067339846965112
#
# Cost at iteration 300 = 1.9061964926874053
#
# Cost at iteration 301 = 1.905659180822425
#
# Cost at iteration 302 = 1.9051220490411904
#
# Cost at iteration 303 = 1.904585097283343
#
# Cost at iteration 304 = 1.9040483254885427
#
# Cost at iteration 305 = 1.9035117335964717
#
# Cost at iteration 306 = 1.9029753215468301
#
# Cost at iteration 307 = 1.902439089279341
#
# Cost at iteration 308 = 1.9019030367337464
#
# Cost at iteration 309 = 1.9013671638498058
#
# Cost at iteration 310 = 1.9008314705673037
#
# Cost at iteration 311 = 1.9002959568260418
#
# Cost at iteration 312 = 1.8997606225658423
#
# Cost at iteration 313 = 1.8992254677265485
#
# Cost at iteration 314 = 1.8986904922480232
#
# Cost at iteration 315 = 1.8981556960701487
#
# Cost at iteration 316 = 1.8976210791312853
#
# Cost at iteration 317 = 1.897086641369944
#
# Cost at iteration 318 = 1.896552382729025
#
# Cost at iteration 319 = 1.8960183031484907
#
# Cost at iteration 320 = 1.8954844025683264
#
# Cost at iteration 321 = 1.894950680928535
#
# Cost at iteration 322 = 1.8944171381691408
#
# Cost at iteration 323 = 1.893883774230188
#
# Cost at iteration 324 = 1.8933505890517404
#
# Cost at iteration 325 = 1.892817582573882
#
# Cost at iteration 326 = 1.8922847547367183
#
# Cost at iteration 327 = 1.8917521054803728
#
# Cost at iteration 328 = 1.8912196347449899
#
# Cost at iteration 329 = 1.8906873424707353
#
# Cost at iteration 330 = 1.890155228597792
#
# Cost at iteration 331 = 1.8896232930663661
#
# Cost at iteration 332 = 1.889091535816682
#
# Cost at iteration 333 = 1.888559956788984
#
# Cost at iteration 334 = 1.8880285559235372
#
# Cost at iteration 335 = 1.887497333160626
#
# Cost at iteration 336 = 1.8869662884405556
#
# Cost at iteration 337 = 1.8864354217036512
#
# Cost at iteration 338 = 1.8859047328902576
#
# Cost at iteration 339 = 1.8853742219407392
#
# Cost at iteration 340 = 1.88484388879548
#
# Cost at iteration 341 = 1.8843137333948874
#
# Cost at iteration 342 = 1.8837837556793844
#
# Cost at iteration 343 = 1.883253955589415
#
# Cost at iteration 344 = 1.8827243330654455
#
# Cost at iteration 345 = 1.8821948880479604
#
# Cost at iteration 346 = 1.8816656204774638
#
# Cost at iteration 347 = 1.8811365302944805
#
# Cost at iteration 348 = 1.8806076174395547
#
# Cost at iteration 349 = 1.8800788818532521
#
# Cost at iteration 350 = 1.8795503234761557
#
# Cost at iteration 351 = 1.8790219422488696
#
# Cost at iteration 352 = 1.8784937381120201
#
# Cost at iteration 353 = 1.8779657110062493
#
# Cost at iteration 354 = 1.8774378608722213
#
# Cost at iteration 355 = 1.8769101876506216
#
# Cost at iteration 356 = 1.8763826912821526
#
# Cost at iteration 357 = 1.8758553717075384
#
# Cost at iteration 358 = 1.8753282288675222
#
# Cost at iteration 359 = 1.8748012627028676
#
# Cost at iteration 360 = 1.8742744731543584
#
# Cost at iteration 361 = 1.873747860162797
#
# Cost at iteration 362 = 1.8732214236690072
#
# Cost at iteration 363 = 1.8726951636138311
#
# Cost at iteration 364 = 1.8721690799381312
#
# Cost at iteration 365 = 1.8716431725827898
#
# Cost at iteration 366 = 1.8711174414887102
#
# Cost at iteration 367 = 1.8705918865968132
#
# Cost at iteration 368 = 1.870066507848042
#
# Cost at iteration 369 = 1.8695413051833578
#
# Cost at iteration 370 = 1.8690162785437416
#
# Cost at iteration 371 = 1.8684914278701945
#
# Cost at iteration 372 = 1.867966753103739
#
# Cost at iteration 373 = 1.8674422541854137
#
# Cost at iteration 374 = 1.8669179310562811
#
# Cost at iteration 375 = 1.866393783655755
#
# Cost at iteration 376 = 1.865869811925332
#
# Cost at iteration 377 = 1.8653460158074031
#
# Cost at iteration 378 = 1.8648223952431062
#
# Cost at iteration 379 = 1.864298950173601
#
# Cost at iteration 380 = 1.8637756805400667
#
# Cost at iteration 381 = 1.8632525862837024
#
# Cost at iteration 382 = 1.862729667345726
#
# Cost at iteration 383 = 1.862206923667376
#
# Cost at iteration 384 = 1.8616843551899103
#
# Cost at iteration 385 = 1.8611619618546054
#
# Cost at iteration 386 = 1.8606397436027602
#
# Cost at iteration 387 = 1.8601177003756904
#
# Cost at iteration 388 = 1.8595958321147328
#
# Cost at iteration 389 = 1.8590741387612437
#
# Cost at iteration 390 = 1.8585526202565996
#
# Cost at iteration 391 = 1.858031276542195
#
# Cost at iteration 392 = 1.8575101075594458
#
# Cost at iteration 393 = 1.8569891132497869
#
# Cost at iteration 394 = 1.856468293554672
#
# Cost at iteration 395 = 1.8559476484155764
#
# Cost at iteration 396 = 1.8554271777739928
#
# Cost at iteration 397 = 1.8549068815714354
#
# Cost at iteration 398 = 1.854386759749436
#
# Cost at iteration 399 = 1.8538668122495476
#
# Cost at iteration 400 = 1.8533470390133433
#
# Cost at iteration 401 = 1.8528274399824138
#
# Cost at iteration 402 = 1.852308015098371
#
# Cost at iteration 403 = 1.8517887643028446
#
# Cost at iteration 404 = 1.8512696875374863
#
# Cost at iteration 405 = 1.8507507847439655
#
# Cost at iteration 406 = 1.8502320558639713
#
# Cost at iteration 407 = 1.8497135008392143
#
# Cost at iteration 408 = 1.8491951196114214
#
# Cost at iteration 409 = 1.8486769121223423
#
# Cost at iteration 410 = 1.8481588783137435
#
# Cost at iteration 411 = 1.8476410181274125
#
# Cost at iteration 412 = 1.8471233315051567
#
# Cost at iteration 413 = 1.8466058183888017
#
# Cost at iteration 414 = 1.8460884787201932
#
# Cost at iteration 415 = 1.8455713124411974
#
# Cost at iteration 416 = 1.8450543194936972
#
# Cost at iteration 417 = 1.8445374998195985
#
# Cost at iteration 418 = 1.844020853360824
#
# Cost at iteration 419 = 1.8435043800593174
#
# Cost at iteration 420 = 1.842988079857041
#
# Cost at iteration 421 = 1.842471952695977
#
# Cost at iteration 422 = 1.841955998518127
#
# Cost at iteration 423 = 1.8414402172655118
#
# Cost at iteration 424 = 1.8409246088801716
#
# Cost at iteration 425 = 1.840409173304167
#
# Cost at iteration 426 = 1.8398939104795766
#
# Cost at iteration 427 = 1.8393788203484984
#
# Cost at iteration 428 = 1.8388639028530522
#
# Cost at iteration 429 = 1.8383491579353741
#
# Cost at iteration 430 = 1.8378345855376217
#
# Cost at iteration 431 = 1.8373201856019705
#
# Cost at iteration 432 = 1.8368059580706169
#
# Cost at iteration 433 = 1.8362919028857758
#
# Cost at iteration 434 = 1.835778019989681
#
# Cost at iteration 435 = 1.8352643093245873
#
# Cost at iteration 436 = 1.8347507708327662
#
# Cost at iteration 437 = 1.834237404456512
#
# Cost at iteration 438 = 1.8337242101381352
#
# Cost at iteration 439 = 1.8332111878199684
#
# Cost at iteration 440 = 1.83269833744436
#
# Cost at iteration 441 = 1.8321856589536814
#
# Cost at iteration 442 = 1.8316731522903213
#
# Cost at iteration 443 = 1.831160817396688
#
# Cost at iteration 444 = 1.8306486542152094
#
# Cost at iteration 445 = 1.8301366626883318
#
# Cost at iteration 446 = 1.8296248427585233
#
# Cost at iteration 447 = 1.8291131943682677
#
# Cost at iteration 448 = 1.828601717460071
#
# Cost at iteration 449 = 1.828090411976457
#
# Cost at iteration 450 = 1.8275792778599693
#
# Cost at iteration 451 = 1.8270683150531701
#
# Cost at iteration 452 = 1.8265575234986422
#
# Cost at iteration 453 = 1.826046903138986
#
# Cost at iteration 454 = 1.8255364539168228
#
# Cost at iteration 455 = 1.8250261757747912
#
# Cost at iteration 456 = 1.824516068655551
#
# Cost at iteration 457 = 1.8240061325017802
#
# Cost at iteration 458 = 1.8234963672561755
#
# Cost at iteration 459 = 1.822986772861073
#
# Cost at iteration 460 = 1.8224773492576478
#
# Cost at iteration 461 = 1.8219680963905962
#
# Cost at iteration 462 = 1.8214590142026932
#
# Cost at iteration 463 = 1.8209501026367314
#
# Cost at iteration 464 = 1.8204413616355246
#
# Cost at iteration 465 = 1.8199327911419032
#
# Cost at iteration 466 = 1.819424391098719
#
# Cost at iteration 467 = 1.8189161614488403
#
# Cost at iteration 468 = 1.8184081021351577
#
# Cost at iteration 469 = 1.8179002131005797
#
# Cost at iteration 470 = 1.8173924942880326
#
# Cost at iteration 471 = 1.816884945640464
#
# Cost at iteration 472 = 1.8163775671008389
#
# Cost at iteration 473 = 1.8158703586121427
#
# Cost at iteration 474 = 1.8153633201173789
#
# Cost at iteration 475 = 1.8148564515595704
#
# Cost at iteration 476 = 1.8143497528817598
#
# Cost at iteration 477 = 1.8138432240270077
#
# Cost at iteration 478 = 1.8133368649383952
#
# Cost at iteration 479 = 1.8128306755589212
#
# Cost at iteration 480 = 1.812324655831084
#
# Cost at iteration 481 = 1.8118188056987417
#
# Cost at iteration 482 = 1.811313125105051
#
# Cost at iteration 483 = 1.8108076139931877
#
# Cost at iteration 484 = 1.8103022723063464
#
# Cost at iteration 485 = 1.8097970999877409
#
# Cost at iteration 486 = 1.8092920969806041
#
# Cost at iteration 487 = 1.8087872632281878
#
# Cost at iteration 488 = 1.8082825986737625
#
# Cost at iteration 489 = 1.8077781032606182
#
# Cost at iteration 490 = 1.8072737769320641
#
# Cost at iteration 491 = 1.806769619631428
#
# Cost at iteration 492 = 1.806265631302056
#
# Cost at iteration 493 = 1.805761811887315
#
# Cost at iteration 494 = 1.805258161330589
#
# Cost at iteration 495 = 1.8047546795752818
#
# Cost at iteration 496 = 1.8042513665648168
#
# Cost at iteration 497 = 1.8037482222426358
#
# Cost at iteration 498 = 1.803245246552199
#
# Cost at iteration 499 = 1.8027424394369862
#
# Cost at iteration 500 = 1.8022398008404965
#
# Cost at iteration 501 = 1.8017373307062465
#
# Cost at iteration 502 = 1.8012350289777734
#
# Cost at iteration 503 = 1.8007328955986317
#
# Cost at iteration 504 = 1.8002309305123976
#
# Cost at iteration 505 = 1.7997291336626626
#
# Cost at iteration 506 = 1.7992275049930395
#
# Cost at iteration 507 = 1.7987260444471598
#
# Cost at iteration 508 = 1.7982247519686723
#
# Cost at iteration 509 = 1.7977236275006154
#
# Cost at iteration 510 = 1.797222670987088
#
# Cost at iteration 511 = 1.796721882372017
#
# Cost at iteration 512 = 1.7962212615991284
#
# Cost at iteration 513 = 1.7957208086121654
#
# Cost at iteration 514 = 1.795220523354893
#
# Cost at iteration 515 = 1.7947204057710917
#
# Cost at iteration 516 = 1.7942204558045634
#
# Cost at iteration 517 = 1.7937206733991267
#
# Cost at iteration 518 = 1.7932210584986221
#
# Cost at iteration 519 = 1.7927216110469053
#
# Cost at iteration 520 = 1.7922223309878527
#
# Cost at iteration 521 = 1.7917232182653595
#
# Cost at iteration 522 = 1.7912242728233398
#
# Cost at iteration 523 = 1.790725494605726
#
# Cost at iteration 524 = 1.79022688355647
#
# Cost at iteration 525 = 1.7897284396195416
#
# Cost at iteration 526 = 1.7892301627389298
#
# Cost at iteration 527 = 1.7887320528586421
#
# Cost at iteration 528 = 1.788234109922706
#
# Cost at iteration 529 = 1.7877363338751653
#
# Cost at iteration 530 = 1.7872387246600856
#
# Cost at iteration 531 = 1.7867412822215494
#
# Cost at iteration 532 = 1.7862440065036573
#
# Cost at iteration 533 = 1.7857468974505302
#
# Cost at iteration 534 = 1.7852499550063075
#
# Cost at iteration 535 = 1.7847531791151465
#
# Cost at iteration 536 = 1.7842565697212243
#
# Cost at iteration 537 = 1.7837601267686864
#
# Cost at iteration 538 = 1.7832638501997942
#
# Cost at iteration 539 = 1.7827677399607824
#
# Cost at iteration 540 = 1.7822717959959027
#
# Cost at iteration 541 = 1.7817760182494238
#
# Cost at iteration 542 = 1.7812804066656351
#
# Cost at iteration 543 = 1.7807849611888442
#
# Cost at iteration 544 = 1.7802896817633767
#
# Cost at iteration 545 = 1.7797945683335774
#
# Cost at iteration 546 = 1.7792996208438092
#
# Cost at iteration 547 = 1.7788048392384554
#
# Cost at iteration 548 = 1.778310223461915
#
# Cost at iteration 549 = 1.7778157734586084
#
# Cost at iteration 550 = 1.7773214891729725
#
# Cost at iteration 551 = 1.7768273705494655
#
# Cost at iteration 552 = 1.776333417532561
#
# Cost at iteration 553 = 1.7758396300667523
#
# Cost at iteration 554 = 1.7753460080965529
#
# Cost at iteration 555 = 1.7748525515645641
#
# Cost at iteration 556 = 1.7743592604170915
#
# Cost at iteration 557 = 1.7738661345988769
#
# Cost at iteration 558 = 1.773373174054507
#
# Cost at iteration 559 = 1.7728803787285867
#
# Cost at iteration 560 = 1.7723877485657404
#
# Cost at iteration 561 = 1.7718952835106103
#
# Cost at iteration 562 = 1.7714029835078573
#
# Cost at iteration 563 = 1.7709108485021614
#
# Cost at iteration 564 = 1.77041887843822
#
# Cost at iteration 565 = 1.7699270732607504
#
# Cost at iteration 566 = 1.769435432914487
#
# Cost at iteration 567 = 1.7689439573441836
#
# Cost at iteration 568 = 1.7684526464946133
#
# Cost at iteration 569 = 1.767961500310566
#
# Cost at iteration 570 = 1.7674705187368511
#
# Cost at iteration 571 = 1.7669797017182964
#
# Cost at iteration 572 = 1.7664890491997483
#
# Cost at iteration 573 = 1.7659985611260705
#
# Cost at iteration 574 = 1.7655082374421478
#
# Cost at iteration 575 = 1.7650180780928804
#
# Cost at iteration 576 = 1.764528083023189
#
# Cost at iteration 577 = 1.7640382521780125
#
# Cost at iteration 578 = 1.7635485855023076
#
# Cost at iteration 579 = 1.7630590829410495
#
# Cost at iteration 580 = 1.762569744439233
#
# Cost at iteration 581 = 1.76208056994187
#
# Cost at iteration 582 = 1.761591559393991
#
# Cost at iteration 583 = 1.7611027127406456
#
# Cost at iteration 584 = 1.7606140299269015
#
# Cost at iteration 585 = 1.7601255108978453
#
# Cost at iteration 586 = 1.7596371555985801
#
# Cost at iteration 587 = 1.7591489639742304
#
# Cost at iteration 588 = 1.7586609359699363
#
# Cost at iteration 589 = 1.7581730715308577
#
# Cost at iteration 590 = 1.757685370602173
#
# Cost at iteration 591 = 1.7571978331290787
#
# Cost at iteration 592 = 1.756710459056789
#
# Cost at iteration 593 = 1.7562232483305378
#
# Cost at iteration 594 = 1.755736200895576
#
# Cost at iteration 595 = 1.7552493166971743
#
# Cost at iteration 596 = 1.75476259568062
#
# Cost at iteration 597 = 1.7542760377912203
#
# Cost at iteration 598 = 1.7537896429742994
#
# Cost at iteration 599 = 1.7533034111752015
#
# Cost at iteration 600 = 1.752817342339288
#
# Cost at iteration 601 = 1.752331436411938
#
# Cost at iteration 602 = 1.7518456933373563
#
# Cost at iteration 603 = 1.751360113061069
#
# Cost at iteration 604 = 1.7508746955295953
#
# Cost at iteration 605 = 1.7503894406883889
#
# Cost at iteration 606 = 1.74990434848292
#
# Cost at iteration 607 = 1.749419418858679
#
# Cost at iteration 608 = 1.7489346517611737
#
# Cost at iteration 609 = 1.74845004713593
#
# Cost at iteration 610 = 1.7479656049284924
#
# Cost at iteration 611 = 1.7474813250844243
#
# Cost at iteration 612 = 1.7469972075493059
#
# Cost at iteration 613 = 1.7465132522687368
#
# Cost at iteration 614 = 1.7460294591883336
#
# Cost at iteration 615 = 1.745545828253733
#
# Cost at iteration 616 = 1.7450623594105883
#
# Cost at iteration 617 = 1.7445790526045717
#
# Cost at iteration 618 = 1.7440959077813734
#
# Cost at iteration 619 = 1.7436129248867023
#
# Cost at iteration 620 = 1.7431301038662848
#
# Cost at iteration 621 = 1.7426474446658657
#
# Cost at iteration 622 = 1.7421649472312086
#
# Cost at iteration 623 = 1.7416826115080937
#
# Cost at iteration 624 = 1.7412004374423216
#
# Cost at iteration 625 = 1.7407184249797092
#
# Cost at iteration 626 = 1.740236574066093
#
# Cost at iteration 627 = 1.739754884647222
#
# Cost at iteration 628 = 1.7392733566671408
#
# Cost at iteration 629 = 1.7387919900736717
#
# Cost at iteration 630 = 1.7383107848127233
#
# Cost at iteration 631 = 1.7378297408302217
#
# Cost at iteration 632 = 1.737348858072112
#
# Cost at iteration 633 = 1.7368681364843566
#
# Cost at iteration 634 = 1.7363875760129364
#
# Cost at iteration 635 = 1.7359071766038507
#
# Cost at iteration 636 = 1.7354269382031162
#
# Cost at iteration 637 = 1.7349468607567684
#
# Cost at iteration 638 = 1.73446694421086
#
# Cost at iteration 639 = 1.7339871885114633
#
# Cost at iteration 640 = 1.7335075936046664
#
# Cost at iteration 641 = 1.733028159436578
#
# Cost at iteration 642 = 1.7325488859533227
#
# Cost at iteration 643 = 1.7320697731010448
#
# Cost at iteration 644 = 1.7315908208259059
#
# Cost at iteration 645 = 1.7311120290740853
#
# Cost at iteration 646 = 1.7306333977917812
#
# Cost at iteration 647 = 1.7301549269252097
#
# Cost at iteration 648 = 1.729676616420603
#
# Cost at iteration 649 = 1.7291984662242148
#
# Cost at iteration 650 = 1.728720476282314
#
# Cost at iteration 651 = 1.728242646541189
#
# Cost at iteration 652 = 1.7277649769471453
#
# Cost at iteration 653 = 1.7272874674465066
#
# Cost at iteration 654 = 1.7268101179856157
#
# Cost at iteration 655 = 1.7263329285108313
#
# Cost at iteration 656 = 1.7258558989685322
#
# Cost at iteration 657 = 1.7253790293051132
#
# Cost at iteration 658 = 1.7249023194668034
#
# Cost at iteration 659 = 1.724425769399638
#
# Cost at iteration 660 = 1.7239493790506497
#
# Cost at iteration 661 = 1.7234731483663055
#
# Cost at iteration 662 = 1.7229970772930907
#
# Cost at iteration 663 = 1.722521165777509
#
# Cost at iteration 664 = 1.7220454137660821
#
# Cost at iteration 665 = 1.7215698212053498
#
# Cost at iteration 666 = 1.7210943880418683
#
# Cost at iteration 667 = 1.7206191142222138
#
# Cost at iteration 668 = 1.7201439996929793
#
# Cost at iteration 669 = 1.7196690444007747
#
# Cost at iteration 670 = 1.7191942482922309
#
# Cost at iteration 671 = 1.7187196113139935
#
# Cost at iteration 672 = 1.718245133412727
#
# Cost at iteration 673 = 1.7177708145351147
#
# Cost at iteration 674 = 1.717296654627857
#
# Cost at iteration 675 = 1.7168226536376718
#
# Cost at iteration 676 = 1.716348811511296
#
# Cost at iteration 677 = 1.7158751281954827
#
# Cost at iteration 678 = 1.715401603637004
#
# Cost at iteration 679 = 1.7149282377826507
#
# Cost at iteration 680 = 1.7144550305792294
#
# Cost at iteration 681 = 1.7139819819735653
#
# Cost at iteration 682 = 1.7135090919125027
#
# Cost at iteration 683 = 1.713036360342902
#
# Cost at iteration 684 = 1.7125637872116417
#
# Cost at iteration 685 = 1.7120913724656193
#
# Cost at iteration 686 = 1.7116191160517487
#
# Cost at iteration 687 = 1.7111470179168509
#
# Cost at iteration 688 = 1.7106750780073092
#
# Cost at iteration 689 = 1.7102032962707707
#
# Cost at iteration 690 = 1.70973167265422
#
# Cost at iteration 691 = 1.709260207104661
#
# Cost at iteration 692 = 1.7087888995691154
#
# Cost at iteration 693 = 1.7083177499946212
#
# Cost at iteration 694 = 1.7078467583282353
#
# Cost at iteration 695 = 1.7073759245170328
#
# Cost at iteration 696 = 1.706905248508105
#
# Cost at iteration 697 = 1.7064347302485623
#
# Cost at iteration 698 = 1.705964369685532
#
# Cost at iteration 699 = 1.7054941667661598
#
# Cost at iteration 700 = 1.7050241214376087
#
# Cost at iteration 701 = 1.7045542336470594
#
# Cost at iteration 702 = 1.7040845033417098
#
# Cost at iteration 703 = 1.703614930468777
#
# Cost at iteration 704 = 1.7031455149754946
#
# Cost at iteration 705 = 1.7026762568091138
#
# Cost at iteration 706 = 1.7022071559169047
#
# Cost at iteration 707 = 1.7017382122461528
#
# Cost at iteration 708 = 1.701269425744164
#
# Cost at iteration 709 = 1.70080079635826
#
# Cost at iteration 710 = 1.7003323240357815
#
# Cost at iteration 711 = 1.6998640087240848
#
# Cost at iteration 712 = 1.6993958503705457
#
# Cost at iteration 713 = 1.6989278489225572
#
# Cost at iteration 714 = 1.6984600043268239
#
# Cost at iteration 715 = 1.6979923165313584
#
# Cost at iteration 716 = 1.6975247854837285
#
# Cost at iteration 717 = 1.6970574111313974
#
# Cost at iteration 718 = 1.696590193421846
#
# Cost at iteration 719 = 1.6961231323025725
#
# Cost at iteration 720 = 1.6956562277210938
#
# Cost at iteration 721 = 1.6951894796249436
#
# Cost at iteration 722 = 1.6947228879616731
#
# Cost at iteration 723 = 1.6942564526788508
#
# Cost at iteration 724 = 1.693790173724064
#
# Cost at iteration 725 = 1.693324051044916
#
# Cost at iteration 726 = 1.692858084589029
#
# Cost at iteration 727 = 1.6923922743040418
#
# Cost at iteration 728 = 1.6919266201361518
#
# Cost at iteration 729 = 1.691461122033857
#
# Cost at iteration 730 = 1.6909957799454851
#
# Cost at iteration 731 = 1.6905305938176762
#
# Cost at iteration 732 = 1.6900655635982036
#
# Cost at iteration 733 = 1.6896006892358355
#
# Cost at iteration 734 = 1.6891359706783333
#
# Cost at iteration 735 = 1.6886714078734761
#
# Cost at iteration 736 = 1.6882070007690617
#
# Cost at iteration 737 = 1.6877427493129042
#
# Cost at iteration 738 = 1.6872786534528352
#
# Cost at iteration 739 = 1.6868147131367048
#
# Cost at iteration 740 = 1.6863509283123796
#
# Cost at iteration 741 = 1.685887298927744
#
# Cost at iteration 742 = 1.6854238249307
#
# Cost at iteration 743 = 1.6849605062691664
#
# Cost at iteration 744 = 1.684497342891081
#
# Cost at iteration 745 = 1.6840343347443971
#
# Cost at iteration 746 = 1.6835714817770868
#
# Cost at iteration 747 = 1.683108783937139
#
# Cost at iteration 748 = 1.682646241171589
#
# Cost at iteration 749 = 1.68218385342828
#
# Cost at iteration 750 = 1.681721620656406
#
# Cost at iteration 751 = 1.6812595428040256
#
# Cost at iteration 752 = 1.6807976198192154
#
# Cost at iteration 753 = 1.6803358516500684
#
# Cost at iteration 754 = 1.679874238244696
#
# Cost at iteration 755 = 1.6794127795512273
#
# Cost at iteration 756 = 1.6789514755178072
#
# Cost at iteration 757 = 1.678490326092599
#
# Cost at iteration 758 = 1.6780293312237837
#
# Cost at iteration 759 = 1.6775684908595592
#
# Cost at iteration 760 = 1.6771078049481412
#
# Cost at iteration 761 = 1.676647273437761
#
# Cost at iteration 762 = 1.6761868962766704
#
# Cost at iteration 763 = 1.6757266734131353
#
# Cost at iteration 764 = 1.6752666047954416
#
# Cost at iteration 765 = 1.674806690371891
#
# Cost at iteration 766 = 1.6743469300908023
#
# Cost at iteration 767 = 1.673887323900513
#
# Cost at iteration 768 = 1.6734278717493762
#
# Cost at iteration 769 = 1.672968573585765
#
# Cost at iteration 770 = 1.6725094293580662
#
# Cost at iteration 771 = 1.6720504390146864
#
# Cost at iteration 772 = 1.6715916025040494
#
# Cost at iteration 773 = 1.6711329197745948
#
# Cost at iteration 774 = 1.6706743907747812
#
# Cost at iteration 775 = 1.6702160154530832
#
# Cost at iteration 776 = 1.669757793757994
#
# Cost at iteration 777 = 1.6692997256380218
#
# Cost at iteration 778 = 1.6688418110416947
#
# Cost at iteration 779 = 1.6683840499175568
#
# Cost at iteration 780 = 1.6679264422141686
#
# Cost at iteration 781 = 1.6674689878801099
#
# Cost at iteration 782 = 1.667011686863976
#
# Cost at iteration 783 = 1.6665545391143797
#
# Cost at iteration 784 = 1.6660975445799358
#
# Cost at iteration 785 = 1.6656407032073288
#
# Cost at iteration 786 = 1.6651840149472024
#
# Cost at iteration 787 = 1.6647274797482385
#
# Cost at iteration 788 = 1.664271097559137
#
# Cost at iteration 789 = 1.663814868328614
#
# Cost at iteration 790 = 1.6633587920054025
#
# Cost at iteration 791 = 1.662902868538254
#
# Cost at iteration 792 = 1.662447097875936
#
# Cost at iteration 793 = 1.661991479967234
#
# Cost at iteration 794 = 1.661536014760949
#
# Cost at iteration 795 = 1.6610807022059026
#
# Cost at iteration 796 = 1.6606255422509302
#
# Cost at iteration 797 = 1.6601705348448854
#
# Cost at iteration 798 = 1.6597156799366395
#
# Cost at iteration 799 = 1.6592609774750802
#
# Cost at iteration 800 = 1.6588064274091128
#
# Cost at iteration 801 = 1.6583520296866672
#
# Cost at iteration 802 = 1.6578977842568554
#
# Cost at iteration 803 = 1.6574436910694539
#
# Cost at iteration 804 = 1.656989750073437
#
# Cost at iteration 805 = 1.6565359612177946
#
# Cost at iteration 806 = 1.6560823244515348
#
# Cost at iteration 807 = 1.6556288397236825
#
# Cost at iteration 808 = 1.6551755069832794
#
# Cost at iteration 809 = 1.6547223261793855
#
# Cost at iteration 810 = 1.6542692972610762
#
# Cost at iteration 811 = 1.6538164201774448
#
# Cost at iteration 812 = 1.6533636948776023
#
# Cost at iteration 813 = 1.652911121310675
#
# Cost at iteration 814 = 1.6524586994258081
#
# Cost at iteration 815 = 1.6520064291721637
#
# Cost at iteration 816 = 1.651554310498898
#
# Cost at iteration 817 = 1.6511023433541214
#
# Cost at iteration 818 = 1.650650527687492
#
# Cost at iteration 819 = 1.6501988634484457
#
# Cost at iteration 820 = 1.649747350586685
#
# Cost at iteration 821 = 1.6492959890514747
#
# Cost at iteration 822 = 1.64884477879209
#
# Cost at iteration 823 = 1.6483937197570921
#
# Cost at iteration 824 = 1.6479428118965371
#
# Cost at iteration 825 = 1.6474920551597578
#
# Cost at iteration 826 = 1.6470414494961017
#
# Cost at iteration 827 = 1.6465909948549347
#
# Cost at iteration 828 = 1.6461406911856398
#
# Cost at iteration 829 = 1.6456905384376161
#
# Cost at iteration 830 = 1.6452405365602802
#
# Cost at iteration 831 = 1.6447906855030654
#
# Cost at iteration 832 = 1.644340985215423
#
# Cost at iteration 833 = 1.6438914356468193
#
# Cost at iteration 834 = 1.6434420367467388
#
# Cost at iteration 835 = 1.642992788464683
#
# Cost at iteration 836 = 1.6425436907501705
#
# Cost at iteration 837 = 1.6420947435527353
#
# Cost at iteration 838 = 1.6416459468219302
#
# Cost at iteration 839 = 1.6411973005073237
#
# Cost at iteration 840 = 1.640748804558502
#
# Cost at iteration 841 = 1.6403004589250678
#
# Cost at iteration 842 = 1.6398522635566402
#
# Cost at iteration 843 = 1.6394042184028559
#
# Cost at iteration 844 = 1.6389563234133686
#
# Cost at iteration 845 = 1.6385085785378481
#
# Cost at iteration 846 = 1.638060983725982
#
# Cost at iteration 847 = 1.637613538927474
#
# Cost at iteration 848 = 1.6371662440920447
#
# Cost at iteration 849 = 1.6367190991694327
#
# Cost at iteration 850 = 1.636272104109392
#
# Cost at iteration 851 = 1.635825258861693
#
# Cost at iteration 852 = 1.6353785633761257
#
# Cost at iteration 853 = 1.6349320176016575
#
# Cost at iteration 854 = 1.6344856214878751
#
# Cost at iteration 855 = 1.6340393749848376
#
# Cost at iteration 856 = 1.6335932780422548
#
# Cost at iteration 857 = 1.6331473306109971
#
# Cost at iteration 858 = 1.6327015326409537
#
# Cost at iteration 859 = 1.6322558840820296
#
# Cost at iteration 860 = 1.6318103848841485
#
# Cost at iteration 861 = 1.6313650349972493
#
# Cost at iteration 862 = 1.6309198343712883
#
# Cost at iteration 863 = 1.6304747829562394
#
# Cost at iteration 864 = 1.6300298807020914
#
# Cost at iteration 865 = 1.629585127558851
#
# Cost at iteration 866 = 1.6291405234765424
#
# Cost at iteration 867 = 1.628696068405205
#
# Cost at iteration 868 = 1.6282517622948955
#
# Cost at iteration 869 = 1.627807605095688
#
# Cost at iteration 870 = 1.6273635967576727
#
# Cost at iteration 871 = 1.626919737230957
#
# Cost at iteration 872 = 1.6264760264656644
#
# Cost at iteration 873 = 1.6260324644119348
#
# Cost at iteration 874 = 1.625589051019926
#
# Cost at iteration 875 = 1.6251457862398122
#
# Cost at iteration 876 = 1.6247026700217837
#
# Cost at iteration 877 = 1.6242597023160483
#
# Cost at iteration 878 = 1.6238168830721584
#
# Cost at iteration 879 = 1.623374212240968
#
# Cost at iteration 880 = 1.6229316897727928
#
# Cost at iteration 881 = 1.6224893156179072
#
# Cost at iteration 882 = 1.6220470897266015
#
# Cost at iteration 883 = 1.6216050120491836
#
# Cost at iteration 884 = 1.6211630825359773
#
# Cost at iteration 885 = 1.6207213011373236
#
# Cost at iteration 886 = 1.6202796678035791
#
# Cost at iteration 887 = 1.619838182484578
#
# Cost at iteration 888 = 1.619396845131058
#
# Cost at iteration 889 = 1.6189556556936204
#
# Cost at iteration 890 = 1.6185146141226892
#
# Cost at iteration 891 = 1.6180737203687037
#
# Cost at iteration 892 = 1.6176329743821225
#
# Cost at iteration 893 = 1.6171923761134182
#
# Cost at iteration 894 = 1.6167519255130816
#
# Cost at iteration 895 = 1.6163116225316194
#
# Cost at iteration 896 = 1.6158714671195558
#
# Cost at iteration 897 = 1.6154314592274295
#
# Cost at iteration 898 = 1.614991598805799
#
# Cost at iteration 899 = 1.614551885804768
#
# Cost at iteration 900 = 1.6141123201751746
#
# Cost at iteration 901 = 1.6136729018678462
#
# Cost at iteration 902 = 1.6132336308334054
#
# Cost at iteration 903 = 1.6127945070222027
#
# Cost at iteration 904 = 1.6123555303846386
#
# Cost at iteration 905 = 1.6119167008700819
#
# Cost at iteration 906 = 1.6114780184310706
#
# Cost at iteration 907 = 1.6110394830183108
#
# Cost at iteration 908 = 1.610601094582524
#
# Cost at iteration 909 = 1.610162853073863
#
# Cost at iteration 910 = 1.609724758443577
#
# Cost at iteration 911 = 1.6092868106425304
#
# Cost at iteration 912 = 1.608849009621512
#
# Cost at iteration 913 = 1.6084113553313262
#
# Cost at iteration 914 = 1.6079738477227932
#
# Cost at iteration 915 = 1.6075364867467514
#
# Cost at iteration 916 = 1.6070992723540556
#
# Cost at iteration 917 = 1.6066622044955756
#
# Cost at iteration 918 = 1.606225283122199
#
# Cost at iteration 919 = 1.605788508184829
#
# Cost at iteration 920 = 1.6053518796328115
#
# Cost at iteration 921 = 1.6049153974183543
#
# Cost at iteration 922 = 1.6044790614927138
#
# Cost at iteration 923 = 1.6040428718068587
#
# Cost at iteration 924 = 1.6036068283117755
#
# Cost at iteration 925 = 1.6031709309584652
#
# Cost at iteration 926 = 1.6027351796979477
#
# Cost at iteration 927 = 1.6022995744807307
#
# Cost at iteration 928 = 1.6018641152582478
#
# Cost at iteration 929 = 1.6014288019817118
#
# Cost at iteration 930 = 1.600993634602208
#
# Cost at iteration 931 = 1.6005586130708358
#
# Cost at iteration 932 = 1.6001237373387136
#
# Cost at iteration 933 = 1.5996890073569738
#
# Cost at iteration 934 = 1.599254423076767
#
# Cost at iteration 935 = 1.5988199844492588
#
# Cost at iteration 936 = 1.5983856914256318
#
# Cost at iteration 937 = 1.5979515439570855
#
# Cost at iteration 938 = 1.5975175419948355
#
# Cost at iteration 939 = 1.5970836854901123
#
# Cost at iteration 940 = 1.596649974394165
#
# Cost at iteration 941 = 1.596216408658257
#
# Cost at iteration 942 = 1.5957829882336698
#
# Cost at iteration 943 = 1.5953497130716998
#
# Cost at iteration 944 = 1.5949165831236614
#
# Cost at iteration 945 = 1.5944835983408834
#
# Cost at iteration 946 = 1.5940507586747117
#
# Cost at iteration 947 = 1.5936180640765085
#
# Cost at iteration 948 = 1.5931855144976532
#
# Cost at iteration 949 = 1.5927531098895407
#
# Cost at iteration 950 = 1.592320850203581
#
# Cost at iteration 951 = 1.5918887353912023
#
# Cost at iteration 952 = 1.591456765403849
#
# Cost at iteration 953 = 1.5910249401929804
#
# Cost at iteration 954 = 1.5905932597100727
#
# Cost at iteration 955 = 1.5901617239066186
#
# Cost at iteration 956 = 1.5897303327341277
#
# Cost at iteration 957 = 1.5892990861441236
#
# Cost at iteration 958 = 1.588867984088149
#
# Cost at iteration 959 = 1.5884370265177614
#
# Cost at iteration 960 = 1.5880062133845332
#
# Cost at iteration 961 = 1.5875755446400563
#
# Cost at iteration 962 = 1.5871450202359354
#
# Cost at iteration 963 = 1.586714640122821
#
# Cost at iteration 964 = 1.5862844042525366
#
# Cost at iteration 965 = 1.585854312577526
#
# Cost at iteration 966 = 1.585424365049459
#
# Cost at iteration 967 = 1.5849945616200236
#
# Cost at iteration 968 = 1.584564902240923
#
# Cost at iteration 969 = 1.5841353868638781
#
# Cost at iteration 970 = 1.5837060154406228
#
# Cost at iteration 971 = 1.5832767879229113
#
# Cost at iteration 972 = 1.5828477042625104
#
# Cost at iteration 973 = 1.582418764411205
#
# Cost at iteration 974 = 1.5819899683207954
#
# Cost at iteration 975 = 1.581561315943099
#
# Cost at iteration 976 = 1.581132807228819
#
# Cost at iteration 977 = 1.5807044421303034
#
# Cost at iteration 978 = 1.580276220600048
#
# Cost at iteration 979 = 1.579848142589934
#
# Cost at iteration 980 = 1.579420208051859
#
# Cost at iteration 981 = 1.5789924169377358
#
# Cost at iteration 982 = 1.578564769199496
#
# Cost at iteration 983 = 1.5781372647890828
#
# Cost at iteration 984 = 1.57770990365846
#
# Cost at iteration 985 = 1.5772826857592293
#
# Cost at iteration 986 = 1.576855611043459
#
# Cost at iteration 987 = 1.5764286794634619
#
# Cost at iteration 988 = 1.5760018909712632
#
# Cost at iteration 989 = 1.5755752455189065
#
# Cost at iteration 990 = 1.5751487430584492
#
# Cost at iteration 991 = 1.5747223835419664
#
# Cost at iteration 992 = 1.5742961669215485
#
# Cost at iteration 993 = 1.573870093149302
#
# Cost at iteration 994 = 1.57344416217735
#
# Cost at iteration 995 = 1.5730183598605922
#
# Cost at iteration 996 = 1.5725926497394342
#
# Cost at iteration 997 = 1.5721670780997965
#
# Cost at iteration 998 = 1.5717416448595787
#
# Cost at iteration 999 = 1.5713163456438664
#
# Cost at iteration 1000 = 1.5708911866462543
#
# [[0.29064392]
#  [0.29064374]
#  [0.2906438 ]
#  [0.29064365]
#  [0.29064354]
#  [0.29064378]
#  [0.2906436 ]
#  [0.2906436 ]
#  [0.29064367]
#  [0.29064357]
#  [0.29064355]
#  [0.29064373]
#  [0.29064371]
#  [0.29064365]
#  [0.2906436 ]
#  [0.29064355]
#  [0.29064368]
#  [0.29064383]
#  [0.29064361]
#  [0.29064371]]

# %%
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('197231-DS-8.ipynb')
# Out:
# File ‘colab_pdf.py’ already there; not retrieving.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-24b2b4dffb85> in <module>()
#       1 get_ipython().system('wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py')
#       2 from colab_pdf import colab_pdf
# ----> 3 colab_pdf('197132-DS-8.ipynb')
#
# /content/colab_pdf.py in colab_pdf(file_name, notebookpath)
#      20     # Check if the notebook exists in the Drive.
#      21     if not os.path.isfile(os.path.join(notebookpath, file_name)):
# ---> 22         raise ValueError(f"file '{file_name}' not found in path '{notebookpath}'.")
#      23
#      24     # Installing all the recommended packages.
#
# ValueError: file '197132-DS-8.ipynb' not found in path '/content/drive/MyDrive/Colab Notebooks/'.
